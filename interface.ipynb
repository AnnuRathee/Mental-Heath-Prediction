# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
import pickle

# %%
df = pd.read_excel("mental_health_india_delhi.xlsx")
df
# Out:
#         ID           Name  Age  Gender  State Employment_Status  \
# 0        1  Vihaan Sharma   42  Female  Delhi     Self-employed
# 1        2  Krishna Gupta   55  Female  Delhi          Employed
# 2        3    Ayaan Mehta   32  Female  Delhi          Employed
# 3        4   Vihaan Singh   34    Male  Delhi     Self-employed
# 4        5    Aditya Jain   63    Male  Delhi          Employed
# ...    ...            ...  ...     ...    ...               ...
# 4995  4996      Sai Verma   37    Male  Delhi     Self-employed
# 4996  4997   Ishaan Verma   39  Female  Delhi          Employed
# 4997  4998     Isha Verma   21    Male  Delhi        Unemployed
# 4998  4999  Krishna Verma   33  Female  Delhi        Unemployed
# 4999  5000    Diya Sharma   38    Male  Delhi           Student
#
#      Mental_Health_Disorder Access_to_Counseling Income_Level  \
# 0                   Anxiety                   No       Middle
# 1                Depression                  Yes          Low
# ...

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# ID                                   0
# Name                                 0
# Age                                  0
# Gender                               0
# State                                0
# Employment_Status                    0
# Mental_Health_Disorder            1573
# Access_to_Counseling                 0
# Income_Level                         0
# Monthly_Income_INR                   0
# Physical_Activity_Level              0
# Sleep_Hours_per_Day                  0
# Stress_Level                         0
# Days_Absent_Work                     0
# Medical_Expenses_per_Month_INR       0
# Support_System_Score                 0
# dtype: int64

# %%
df.Mental_Health_Disorder.fillna("None",inplace = True)
print(df.isnull().sum())
# Out:
# ID                                0
# Name                              0
# Age                               0
# Gender                            0
# State                             0
# Employment_Status                 0
# Mental_Health_Disorder            0
# Access_to_Counseling              0
# Income_Level                      0
# Monthly_Income_INR                0
# Physical_Activity_Level           0
# Sleep_Hours_per_Day               0
# Stress_Level                      0
# Days_Absent_Work                  0
# Medical_Expenses_per_Month_INR    0
# Support_System_Score              0
# dtype: int64
# C:\Users\Annu Rathee\AppData\Local\Temp\ipykernel_7876\1528746425.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df['Stress_Level'].unique()
# Out:
# array(['Moderate', 'Low', 'High'], dtype=object)

# %%
df['Stress_Level']=df['Stress_Level'].map({'Low':0, 'Moderate':1,  'High':2})
df
# Out:
#         ID           Name  Age  Gender  State Employment_Status  \
# 0        1  Vihaan Sharma   42  Female  Delhi     Self-employed
# 1        2  Krishna Gupta   55  Female  Delhi          Employed
# 2        3    Ayaan Mehta   32  Female  Delhi          Employed
# 3        4   Vihaan Singh   34    Male  Delhi     Self-employed
# 4        5    Aditya Jain   63    Male  Delhi          Employed
# ...    ...            ...  ...     ...    ...               ...
# 4995  4996      Sai Verma   37    Male  Delhi     Self-employed
# 4996  4997   Ishaan Verma   39  Female  Delhi          Employed
# 4997  4998     Isha Verma   21    Male  Delhi        Unemployed
# 4998  4999  Krishna Verma   33  Female  Delhi        Unemployed
# 4999  5000    Diya Sharma   38    Male  Delhi           Student
#
#      Mental_Health_Disorder Access_to_Counseling Income_Level  \
# 0                   Anxiety                   No       Middle
# 1                Depression                  Yes          Low
# ...

# %%
X = df[['Age', 'Monthly_Income_INR', 'Medical_Expenses_per_Month_INR', 'Sleep_Hours_per_Day', 'Support_System_Score']]
y = df['Stress_Level']

# %%
# Splitting the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=77
                                                    )

# Initialize the GaussianNB model
model = GaussianNB()

# Train the model
model.fit(X_train, y_train)

# Evaluate the model
accuracy = model.score(X_test, y_test)
print(f"Model Accuracy: {accuracy * 100:.2f}%")

# Save the model
with open('gaussian_naive_bayes_model.pkl', 'wb') as f:
    pickle.dump(model, f)
print("Model saved as 'gaussian_naive_bayes_model.pkl'")
# Out:
# Model Accuracy: 42.80%
# Model saved as 'gaussian_naive_bayes_model.pkl'
