# %% [markdown]
# # Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("mental_health_india_delhi.xlsx")
df
# Out:
#         ID           Name  Age  Gender  State Employment_Status  \
# 0        1  Vihaan Sharma   42  Female  Delhi     Self-employed
# 1        2  Krishna Gupta   55  Female  Delhi          Employed
# 2        3    Ayaan Mehta   32  Female  Delhi          Employed
# 3        4   Vihaan Singh   34    Male  Delhi     Self-employed
# 4        5    Aditya Jain   63    Male  Delhi          Employed
# ...    ...            ...  ...     ...    ...               ...
# 4995  4996      Sai Verma   37    Male  Delhi     Self-employed
# 4996  4997   Ishaan Verma   39  Female  Delhi          Employed
# 4997  4998     Isha Verma   21    Male  Delhi        Unemployed
# 4998  4999  Krishna Verma   33  Female  Delhi        Unemployed
# 4999  5000    Diya Sharma   38    Male  Delhi           Student
#
#      Mental_Health_Disorder Access_to_Counseling Income_Level  \
# 0                   Anxiety                   No       Middle
# 1                Depression                  Yes          Low
# ...

# %% [markdown]
# # Dataset Basic Information Gathering

# %%
print("\n--- Descriptive Statistics ---")
print(df.describe())
# Out:
# --- Descriptive Statistics ---
#                 ID          Age  Monthly_Income_INR  Sleep_Hours_per_Day  \
# count  5000.000000  5000.000000         5000.000000          5000.000000
# mean   2500.500000    40.907600        78341.107000             6.513920
# std    1443.520003    13.461222        41834.185203             1.466372
# min       1.000000    18.000000         5055.000000             0.900000
# 25%    1250.750000    29.000000        42173.500000             5.500000
# 50%    2500.500000    41.000000        78678.000000             6.500000
# 75%    3750.250000    53.000000       114748.750000             7.500000
# max    5000.000000    64.000000       149991.000000            11.700000
#
#        Days_Absent_Work  Medical_Expenses_per_Month_INR  Support_System_Score
# count       5000.000000                     5000.000000           5000.000000
# mean           1.978400                    10277.480800              5.492000
# ...

# %%
print("Dataset Info:")
print(df.info())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              5000 non-null   int64
#  1   Name                            5000 non-null   object
#  2   Age                             5000 non-null   int64
#  3   Gender                          5000 non-null   object
#  4   State                           5000 non-null   object
#  5   Employment_Status               5000 non-null   object
#  6   Mental_Health_Disorder          3427 non-null   object
#  7   Access_to_Counseling            5000 non-null   object
#  8   Income_Level                    5000 non-null   object
#  9   Monthly_Income_INR              5000 non-null   int64
#  10  Physical_Activity_Level         5000 non-null   object
#  11  Sleep_Hours_per_Day             5000 non-null   float64
# ...

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# ID                                   0
# Name                                 0
# Age                                  0
# Gender                               0
# State                                0
# Employment_Status                    0
# Mental_Health_Disorder            1573
# Access_to_Counseling                 0
# Income_Level                         0
# Monthly_Income_INR                   0
# Physical_Activity_Level              0
# Sleep_Hours_per_Day                  0
# Stress_Level                         0
# Days_Absent_Work                     0
# Medical_Expenses_per_Month_INR       0
# Support_System_Score                 0
# dtype: int64

# %%
df.Mental_Health_Disorder.fillna("None",inplace = True)
print(df.isnull().sum())
# Out:
# ID                                0
# Name                              0
# Age                               0
# Gender                            0
# State                             0
# Employment_Status                 0
# Mental_Health_Disorder            0
# Access_to_Counseling              0
# Income_Level                      0
# Monthly_Income_INR                0
# Physical_Activity_Level           0
# Sleep_Hours_per_Day               0
# Stress_Level                      0
# Days_Absent_Work                  0
# Medical_Expenses_per_Month_INR    0
# Support_System_Score              0
# dtype: int64
# C:\Users\Annu Rathee\AppData\Local\Temp\ipykernel_11212\1528746425.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
print("\nDuplicate Entries:", df.duplicated().sum())
df = df.drop_duplicates()
# Out:
# Duplicate Entries: 0

# %%
# Value Counts for Categorical Variables
print("\n--- Value Counts ---")
for col in ['Gender', 'Employment_Status', 'Mental_Health_Disorder', 'Access_to_Counseling', 'Income_Level', 'Stress_Level']:
    print(f"\n{col} Value Counts:\n", df[col].value_counts())
# Out:
# --- Value Counts ---
#
# Gender Value Counts:
#  Gender
# Male      2415
# Female    2398
# Other      187
# Name: count, dtype: int64
#
# Employment_Status Value Counts:
#  Employment_Status
# Self-employed    1298
# Unemployed       1267
# Employed         1228
# Student          1207
# Name: count, dtype: int64
#
# Mental_Health_Disorder Value Counts:
#  Mental_Health_Disorder
# Anxiety             1469
# Depression          1240
# Bipolar Disorder     470
# PTSD                 248
# Name: count, dtype: int64
#
# Access_to_Counseling Value Counts:
#  Access_to_Counseling
# No     3021
# Yes    1979
# Name: count, dtype: int64
#
# Income_Level Value Counts:
#  Income_Level
# Middle    2207
# Low       2037
# High       756
# Name: count, dtype: int64
#
# Stress_Level Value Counts:
#  Stress_Level
# Moderate    1963
# Low         1531
# High        1506
# Name: count, dtype: int64

# %% [markdown]
# # Data Visualization

# %%
sns.set(style="whitegrid")

# %%
# Gender Distribution
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x="Gender", palette="pastel")
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Annu Rathee\AppData\Local\Temp\ipykernel_11212\3357498030.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="Gender", palette="pastel")

# %%
# Mental Health Disorders Count
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x="Mental_Health_Disorder", order=df['Mental_Health_Disorder'].value_counts().index, palette="Set2")
plt.title("Mental Health Disorder Distribution")
plt.xlabel("Disorder Type")
plt.ylabel("Count")
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Annu Rathee\AppData\Local\Temp\ipykernel_11212\3597935063.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="Mental_Health_Disorder", order=df['Mental_Health_Disorder'].value_counts().index, palette="Set2")

# %%
def plot_count(column):
    plt.figure(figsize=(8, 5))
    sns.countplot(data=df, x=column, palette='Set3')
    plt.title(f"{column.replace('_', ' ')} Count")
    plt.xticks(rotation=30)
    plt.tight_layout()
    plt.show()

# Example usage:
plot_count('Income_Level')
plot_count('Gender')
# Out:
# C:\Users\Annu Rathee\AppData\Local\Temp\ipykernel_11212\2332954430.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=column, palette='Set3')
# C:\Users\Annu Rathee\AppData\Local\Temp\ipykernel_11212\2332954430.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=column, palette='Set3')

# %%
# Plot distributions
num_cols = ['Age', 'Monthly_Income_INR', 'Medical_Expenses_per_Month_INR', 'Sleep_Hours_per_Day']
for col in num_cols:
    plt.figure(figsize=(8, 5))
    sns.histplot(df[col], kde=True, color='teal')
    plt.title(f"Distribution of {col.replace('_', ' ')}")
    plt.tight_layout()
    plt.show()

# %%
# Income vs Stress Level
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x="Stress_Level", y="Monthly_Income_INR", palette="coolwarm")
plt.title("Monthly Income by Stress Level")
plt.xlabel("Stress Level")
plt.ylabel("Monthly Income (INR)")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Annu Rathee\AppData\Local\Temp\ipykernel_11212\2792721967.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="Stress_Level", y="Monthly_Income_INR", palette="coolwarm")

# %%
# Support System Score
plt.figure(figsize=(7, 4))
sns.countplot(data=df, x="Support_System_Score", palette="YlGnBu")
plt.title("Support System Score")
plt.xlabel("Score (1 to 10)")
plt.ylabel("Count")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Annu Rathee\AppData\Local\Temp\ipykernel_11212\3357096439.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="Support_System_Score", palette="YlGnBu")

# %%
# Show annotations on bar plots
plt.figure(figsize=(7, 5))
ax = sns.countplot(data=df, x='Stress_Level', palette='pastel')
for container in ax.containers:
    ax.bar_label(container)
plt.title("Stress Level Distribution")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Annu Rathee\AppData\Local\Temp\ipykernel_11212\1380072106.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='Stress_Level', palette='pastel')

# %%
# Correlation Heatmap 
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap of Numerical Features")
plt.tight_layout()
plt.show()

# %%
#  Pie Chart: Stress Level Distribution 
plt.figure(figsize=(6, 6))
df['Stress_Level'].value_counts().plot.pie(autopct='%1.1f%%', startangle=140, colors=['lightcoral', 'gold', 'lightgreen'])
plt.title("Stress Level Distribution")
plt.ylabel("")
plt.tight_layout()
plt.show()

# %%
# Disorder vs Age Distribution
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Mental_Health_Disorder', y='Age', palette='cool')
plt.title("Age vs Mental Health Disorders")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Annu Rathee\AppData\Local\Temp\ipykernel_11212\3304902657.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Mental_Health_Disorder', y='Age', palette='cool')

# %%
# Disorder vs Income
plt.figure(figsize=(10, 6))
sns.violinplot(data=df, x='Mental_Health_Disorder', y='Monthly_Income_INR', palette='muted')
plt.title("Income Distribution across Disorders")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Annu Rathee\AppData\Local\Temp\ipykernel_11212\2620630886.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Mental_Health_Disorder', y='Monthly_Income_INR', palette='muted')

# %% [markdown]
# # Statistial Analysis of Data

# %%
#  Average Sleep by Stress Level 
avg_sleep = df.groupby('Stress_Level')['Sleep_Hours_per_Day'].mean()
print("\nAverage Sleep Hours per Day by Stress Level:\n", avg_sleep)
# Out:
# Average Sleep Hours per Day by Stress Level:
#  Stress_Level
# High        6.516733
# Low         6.543762
# Moderate    6.488487
# Name: Sleep_Hours_per_Day, dtype: float64

# %%
# Grouped Mean: Income Level vs Support Score 
support_income = df.groupby("Income_Level")["Support_System_Score"].mean()
print("\nAverage Support System Score by Income Level:\n", support_income)
# Out:
# Average Support System Score by Income Level:
#  Income_Level
# High      5.489418
# Low       5.443790
# Middle    5.537381
# Name: Support_System_Score, dtype: float64

# %%
# Encode categorical data
from sklearn.preprocessing import StandardScaler, LabelEncoder
label_cols = ['Gender', 'Employment_Status', 'Mental_Health_Disorder', 'Access_to_Counseling', 'Income_Level', 'Stress_Level']
label_encoders = {}
for col in label_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
# Average support score by counseling access
counsel_support = df.groupby("Access_to_Counseling")["Support_System_Score"].mean()
print("\nAverage Support Score by Counseling Access:\n", counsel_support)
# Out:
# Average Support Score by Counseling Access:
#  Access_to_Counseling
# 0    5.537570
# 1    5.422436
# Name: Support_System_Score, dtype: float64

# %%
# Pivot: Mean sleep per stress level per income level
pivot_sleep = pd.pivot_table(df, values='Sleep_Hours_per_Day',
                              index='Income_Level', columns='Stress_Level', aggfunc='mean')
print("\nPivot Table - Sleep Hours by Income & Stress:\n", pivot_sleep)
# Out:
# Pivot Table - Sleep Hours by Income & Stress:
#  Stress_Level         0         1         2
# Income_Level
# 0             6.681739  6.475214  6.417808
# 1             6.437438  6.597615  6.510138
# 2             6.532234  6.517066  6.492317

# %%
# Cross-tab: Gender vs Stress Level
crosstab = pd.crosstab(df['Gender'], df['Stress_Level'], normalize='index') * 100
print("\nPercentage Distribution of Stress Level by Gender:\n", crosstab.round(2))
# Out:
# Percentage Distribution of Stress Level by Gender:
#  Stress_Level      0      1      2
# Gender
# 0             29.94  30.28  39.78
# 1             29.94  30.89  39.17
# 2             34.76  31.55  33.69

# %%
# . Hypothesis Testing 
# Compare sleep between high stress (encoded as 2) vs low stress (encoded as 0)
from scipy.stats import ttest_ind
high_stress = df[df['Stress_Level'] == 2]['Sleep_Hours_per_Day']
low_stress = df[df['Stress_Level'] == 0]['Sleep_Hours_per_Day']
t_stat, p_val = ttest_ind(high_stress, low_stress)
print(f"\nT-test (High vs Low Stress Sleep): t={t_stat:.2f}, p={p_val:.4f}")
# Out:
# T-test (High vs Low Stress Sleep): t=-0.56, p=0.5760

# %%
from scipy.stats import skew, kurtosis

print("\n--- Skewness & Kurtosis ---")
for col in ['Monthly_Income_INR', 'Medical_Expenses_per_Month_INR', 'Sleep_Hours_per_Day']:
    print(f"{col} - Skewness: {skew(df[col]):.2f}, Kurtosis: {kurtosis(df[col]):.2f}")
# Out:
# --- Skewness & Kurtosis ---
# Monthly_Income_INR - Skewness: -0.02, Kurtosis: -1.19
# Medical_Expenses_per_Month_INR - Skewness: 0.00, Kurtosis: -1.21
# Sleep_Hours_per_Day - Skewness: -0.03, Kurtosis: -0.10

# %% [markdown]
# # Machine Learning

# %%
X = df[['Age', 'Monthly_Income_INR', 'Medical_Expenses_per_Month_INR', 'Sleep_Hours_per_Day', 'Support_System_Score']]
y = df['Stress_Level']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.50, random_state=40)

# %% [markdown]
# # Logistic Regression

# %%
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# Model Evaluation
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("Accuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.36      0.01      0.01       763
#            1       1.00      0.00      0.00       771
#            2       0.39      0.99      0.56       966
#
#     accuracy                           0.39      2500
#    macro avg       0.58      0.33      0.19      2500
# weighted avg       0.57      0.39      0.22      2500
#
# Confusion Matrix:
# [[  4   0 759]
#  [  1   1 769]
#  [  6   0 960]]
# Accuracy Score: 0.386
# C:\Users\Annu Rathee\Desktop\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print("Decision Tree Results:")
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print("Accuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# Decision Tree Results:
#               precision    recall  f1-score   support
#
#            0       0.31      0.31      0.31       763
#            1       0.30      0.30      0.30       771
#            2       0.37      0.38      0.38       966
#
#     accuracy                           0.33      2500
#    macro avg       0.33      0.33      0.33      2500
# weighted avg       0.33      0.33      0.33      2500
#
# [[234 230 299]
#  [224 229 318]
#  [291 307 368]]
# Accuracy Score: 0.3324

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print("Random Forest Results:")
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print("Accuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# Random Forest Results:
#               precision    recall  f1-score   support
#
#            0       0.30      0.25      0.28       763
#            1       0.31      0.25      0.27       771
#            2       0.39      0.51      0.45       966
#
#     accuracy                           0.35      2500
#    macro avg       0.34      0.34      0.33      2500
# weighted avg       0.34      0.35      0.34      2500
#
# [[193 192 378]
#  [196 189 386]
#  [244 226 496]]
# Accuracy Score: 0.3512

# %% [markdown]
# # K Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(n_neighbors=5)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print("KNN Results:")
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print("Accuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# KNN Results:
#               precision    recall  f1-score   support
#
#            0       0.29      0.37      0.32       763
#            1       0.30      0.27      0.28       771
#            2       0.40      0.34      0.37       966
#
#     accuracy                           0.33      2500
#    macro avg       0.33      0.33      0.32      2500
# weighted avg       0.33      0.33      0.33      2500
#
# [[284 244 235]
#  [317 207 247]
#  [390 250 326]]
# Accuracy Score: 0.3268

# %% [markdown]
# # Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

model = GaussianNB()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print("Naive Bayes Results:")
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print("Accuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       763
#            1       0.00      0.00      0.00       771
#            2       0.39      1.00      0.56       966
#
#     accuracy                           0.39      2500
#    macro avg       0.13      0.33      0.19      2500
# weighted avg       0.15      0.39      0.22      2500
#
# [[  0   0 763]
#  [  0   0 771]
#  [  0   0 966]]
# Accuracy Score: 0.3864
# C:\Users\Annu Rathee\Desktop\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.svm import SVC

model = SVC()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print("SVM Results:")
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print("Accuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# SVM Results:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       763
#            1       0.00      0.00      0.00       771
#            2       0.39      1.00      0.56       966
#
#     accuracy                           0.39      2500
#    macro avg       0.13      0.33      0.19      2500
# weighted avg       0.15      0.39      0.22      2500
#
# [[  0   0 763]
#  [  0   0 771]
#  [  0   0 966]]
# Accuracy Score: 0.3864
# C:\Users\Annu Rathee\Desktop\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...
